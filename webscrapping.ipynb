# %% [markdown]
# <a href="https://colab.research.google.com/github/idyweb/WebScraping/blob/master/webscrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#webscrapping

# %%
pip install requests

# %%
pip install bs4

# %%
#import libraries
import requests
from bs4 import BeautifulSoup as bs

# %%
#create a vairable that will collect the users github username
github_user = input('Input Github User: ')
#enter the url you want to scrap
url = 'https://github.com/'+github_user
#send request to the url
r = requests.get(url)
#use beautiful soup to get the request you wanted
soup= bs(r.content, 'html.parser')
profile_image = soup.find('img', {'alt':'Avatar'})['src']
print(profile_image)
# Out:
# Input Github User: idyweb
# https://avatars.githubusercontent.com/u/52932570?v=4
